# %% [markdown]
# ### $L^2$ Norm

# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([77, 7, 7])
x
# Out:
# array([77,  7,  7])

# %%
# hitung nilai L2 norm dari vector x
(77**2 + 7**2 + 7**2)**(1/2)
# Out:
# 77.63375554486592

# %% [markdown]
# ### Unit Norms

# %%
# buat vector v dengan elemen (3,4)
v = np.array([3, 4])

# hitung nilai L2 norm dari vector v
norm = np.linalg.norm(v)

# tampilkan unit vector dari vector v
unit_v = v / norm

# hitung panjang unit vector dari vector v
norm_unit = np.linalg.norm(unit_v)

print("Vektor asli:", v)
print("Panjang vektor:", norm)
print("Unit vector:", unit_v)
print("Panjang unit vector:", norm_unit)
# Out:
# Vektor asli: [3 4]
# Panjang vektor: 5.0
# Unit vector: [0.6 0.8]
# Panjang unit vector: 1.0

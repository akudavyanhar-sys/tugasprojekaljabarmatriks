# %% [markdown]
# ### Vektor

# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([77, 7, 7])
x
# Out:
# array([77,  7,  7])

# %%
# hitung panjang vector x
len(x)
# Out:
# 3

# %%
# tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
# tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
# akses elemen pertama dari vector x
x[0]
# Out:
# np.int64(77)

# %%
# tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# ### Vektor Transpose

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([77,  7,  7])

# %%
# tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
# buat vector y dengan ukuran 3x1
y = np.array([[75, 7, 5]])
y
# Out:
# array([[75,  7,  5]])

# %%
# tampilkan ukuran vector y
y.shape
# Out:
# (1, 3)

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t
y_t = y.T
y_t
# Out:
# array([[75],
#        [ 7],
#        [ 5]])

# %%
# tampilkan ukuran dari vector y_t
y_t.shape
# Out:
# (3, 1)

# %% [markdown]
# ### Vectors in PyTorch and TensorFlow

# %%
# lakukan soal nomor 2 menggunakan pytorch dan tensorflow
import torch
import tensorflow as tf

# %%
x_pt = torch.tensor([77, 7, 7])
x_pt
# Out:
# tensor([77,  7,  7])

# %%
x_tf = tf.Variable([77, 7, 7])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([77,  7,  7], dtype=int32)>

# %% [markdown]
# ### Matrix menggunakan NumPy

# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[77,7], [7, 77], [70, 7]])
X
# Out:
# array([[77,  7],
#        [ 7, 77],
#        [70,  7]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (3, 2)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([77,  7, 70])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([ 7, 77])

# %% [markdown]
# ### Matrix menggunakan PyTorch

# %%
import torch

# %%
# ulangi soal nomor 1 menggunakan pytorch
X_pt = torch.tensor([[77,7], [7, 77], [70, 7]])
X_pt
# Out:
# tensor([[77,  7],
#         [ 7, 77],
#         [70,  7]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
X_pt[1,:]
# Out:
# tensor([ 7, 77])

# %% [markdown]
# ### Matrix menggunakan TensorFlow

# %%
import tensorflow as tf

# %%
# ulangi soal nomor 1 menggunakan tensorflow
X_tf = tf.Variable([[77,7], [7, 77], [70, 7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[77,  7],
#        [ 7, 77],
#        [70,  7]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([ 7, 77], dtype=int32)>
